# %%
# %%writefile baid_t1.inp
# 1 2

# %%
# %%writefile baid_t2.inp
# -1 -2

# %%
# !cmd /c "g++ baid.cpp -std=c++17 -O2 -Wall -Wextra -o baid.exe"
# !cmd /c "baid.exe < baid_t1.inp"
# !cmd /c "baid.exe < baid_t2.inp "
