# %%
# %%writefile baie_t1.inp
# 11 5 3 11

# %%
# %%writefile baie_t2.inp
# 11 5 11 11

# %%
# %%writefile baie_t3.inp
# 5 6 1 6

# %%
# %%writefile baie_t4.inp
# 1 12 3 12

# %%
# %%writefile baie_t5.inp
# 1 12 20 20

# %%
# %%writefile baie_t6.inp
# 6 4 5 6

# %%
# %%writefile baie_t7.inp
# 1 2 13 13

# %%
# %%writefile baie_t8.inp
# 1 5 4 5

# %%
# %%writefile baie_t9.inp
# 13 1 4 13

# %%
# %%writefile baie_t10.inp
# 6 6 6 6

# %%
# %%writefile baie_t11.inp
# 6 4 6 6

# %%
# %%writefile baie_t12.inp
# 4 6 6 6

# %%
# %%writefile baie_t13.inp
# 6 6 4 6

# %%
# !cmd /c "g++ baie.cpp -std=c++17 -O2 -Wall -Wextra -o baie.exe"
# !cmd /c "baie.exe < baie_t1.inp"
# !cmd /c "baie.exe < baie_t2.inp"
# !cmd /c "baie.exe < baie_t3.inp"
# !cmd /c "baie.exe < baie_t4.inp"
# !cmd /c "baie.exe < baie_t5.inp"
# !cmd /c "baie.exe < baie_t6.inp"
# !cmd /c "baie.exe < baie_t7.inp"
# !cmd /c "baie.exe < baie_t8.inp"
# !cmd /c "baie.exe < baie_t9.inp"
# !cmd /c "baie.exe < baie_t10.inp"
# !cmd /c "baie.exe < baie_t11.inp"
# !cmd /c "baie.exe < baie_t12.inp"
# !cmd /c "baie.exe < baie_t13.inp"
