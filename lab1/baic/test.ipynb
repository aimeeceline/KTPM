# %%
# %%writefile baic_t1.inp
# 1 -1

# %%
# %%writefile baic_t2.inp
# 5 10

# %%
# %%writefile baic_t3.inp
# 12 24

# %%
# !cmd /c "g++ baic.cpp -std=c++17 -O2 -Wall -Wextra -o baic.exe"
# !cmd /c "baic.exe < baic_t1.inp"
# !cmd /c "baic.exe < baic_t2.inp"
# !cmd /c "baic.exe < baic_t3.inp"
