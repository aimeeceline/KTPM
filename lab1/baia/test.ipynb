# %%
# %%writefile baia_t1.inp
# 11
# Out:
# Writing baia_t1.inp

# %%
# %%writefile baia_t2.inp
# 5
# Out:
# Writing baia_t2.inp

# %%
# !cmd /c "g++ baia.cpp -std=c++17 -O2 -Wall -Wextra -o baia.exe"

# %%
# Cách 1: từng lệnh
# !cmd /c "baia.exe < baia_t1.inp"
# !cmd /c "baia.exe < baia_t2.inp "
# Out:
# 22
# -5
