# %%
# %%writefile baib_t1.inp
# 11

# %%
# %%writefile baib_t2.inp
# 5

# %%
# !cmd /c "g++ baib.cpp -std=c++17 -O2 -Wall -Wextra -o baib.exe"

# %%
# Cách 1: từng lệnh
# !cmd /c "baib.exe < baib_t1.inp"
# !cmd /c "baib.exe < baib_t2.inp "
# Out:
# 22
# -5
