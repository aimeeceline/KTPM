# %%
# !g++ test_quartic.cpp -std=c++17 -O2 -Wall -Wextra -o test_quartic.exe
# !cmd /c "test_quartic.exe"
# Out:
# [PASS] T1 infinite | expectedN=-1 gotN=-1
# [PASS] T2 no-solution | expectedN=0 gotN=0
# [PASS] T3 linear y>0 | expectedN=2 gotN=2 | got: -2 2
# [FAIL] T4 linear y=0  (should be 1) | expectedN=1 gotN=2 | got: 0 0
# [PASS] T5 linear y<0 | expectedN=0 gotN=0
# [PASS] T6 quad Δ<0 | expectedN=0 gotN=0
# [PASS] T7 Δ=0 but y<0 | expectedN=0 gotN=0
# [PASS] T8 Δ=0 y=1 | expectedN=2 gotN=2 | got: -1 1
# [FAIL] T9 y1=y2=0 (should be 1) | expectedN=1 gotN=2 | got: 0 0
# [PASS] T10 two y>0 | expectedN=4 gotN=4 | got: -2 -1 1 2
# [PASS] T11 one y>0 | expectedN=2 gotN=2 | got: -1 1
# [PASS] T12 both y<0 | expectedN=0 gotN=0
#
# Summary: 10/12 passed
